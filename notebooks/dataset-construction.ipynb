# %%
import os
print(os.getcwd())
# Out:
# /home/joy/Desktop/mechinterp-typoglycemia

# %%
os.chdir("/home/joy/Desktop/mechinterp-typoglycemia")
print(os.getcwd())
# Out:
# /home/joy/Desktop/mechinterp-typoglycemia

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/joy/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import data_utils

# %%
sentences=data_utils.load_raw_sentences("data/raw/random-english-words.txt")
print(sentences)
# Out:
# ['The quick brown fox jumps over the lazy dog.', 'My Mum tries to be cool by saying that she likes all the same things that I do.', 'A purple pig and a green donkey flew a kite in the middle of the night and ended up sunburnt.', 'Last Friday I saw a spotted striped blue worm shake hands with a legless lizard.', "A song can make or ruin a person's day if they let it get to them.", "Sometimes it is better to just walk away from things and go back to them later when you're in a better frame of mind.", 'Writing a list of random sentences is harder than I initially thought it would be.', 'Lets all be unique together until we realise we are all the same.', "If I don't like something, I'll stay away from it.", 'I love eating toasted cheese and tuna sandwiches.', "If you like tuna and tomato sauce, try combining the two. It's really not as bad as it sounds.", "Someone I know recently combined Maple Syrup and buttered Popcorn thinking it would taste like caramel popcorn. It didn't and they do
# ...

# %%
#sentences=nltk.sent_tokenize(prose_text)
#print(sentences)

# %%
cst_list = data_utils.build_cst_triplets(sentences)
print(cst_list)
# Out:
# [{'clean_context': 'The quick brown fox jumps over the lazy', 'scrambled_context': 'The qucik brwon fox jpmus oevr the lzay', 'target': 'dog'}, {'clean_context': 'My Mum tries to be cool by saying that she likes all the same things that I', 'scrambled_context': 'My Mum tiers to be cool by syinag taht she lieks all the smae thgins taht I', 'target': 'do'}, {'clean_context': 'A purple pig and a green donkey flew a kite in the middle of the night and ended up', 'scrambled_context': 'A puprle pig and a geern dknoey felw a ktie in the mdldie of the nhgit and edned up', 'target': 'sunburnt'}, {'clean_context': 'Last Friday I saw a spotted striped blue worm shake hands with a legless', 'scrambled_context': 'Lsat Faridy I saw a seopttd sepirtd bule wrom sahke hnads wtih a lesgles', 'target': 'lizard'}, {'clean_context': "A song can make or ruin a person's day if they let it get to", 'scrambled_context': "A snog can mkae or riun a po'rnses day if tehy let it get to", 'target': 'them'}, {'clea
# ...

# %%
data_utils.generate_cst_json(cst_list)
